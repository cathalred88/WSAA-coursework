# %% [markdown]
# ## Assignment 3 : Exchequer Account Historical Series
# # Author Cathal Redmond
# # Date 14 April 2026

# %%
# define imports i will need
import json
import requests 
url = "https://ws.cso.ie/public/api.restful/PxStat.Data.Cube_API.ReadDataset/FIQ02/JSON-stat/2.0/"

response = requests.get(url)
data = response.json()
with open('CSO.json', 'w') as f:
    json.dump(data, f)
# load the data from the json file
with open('CSO.json', 'r') as f:
    data = json.load(f)

'''
# print the data to see what it looks like
print(data)
# extract the relevant data from the json file
# the data is in the "value" key of the json file
values_list = data['value']
# print the values to see what they look like

print(values_list)
# the years are in the dimension 'TLIST(Q1)'
years = list(data['dimension']['TLIST(Q1)']['category']['label'].values())
# print the years and values to see what they look like
print(years)
print(values_list)
# we can now create a line graph of the data using matplotlib
import matplotlib.pyplot as plt

# Extract category labels
categories = list(data['dimension']['C02568V03113']['category']['label'].values())
plt.figure(figsize=(10, 6))

# Plot each series
for i in range(len(categories)):
    series = values_list[i * len(years):(i + 1) * len(years)]
    plt.plot(years, series, label=categories[i])

plt.xlabel('Year')
plt.xticks(rotation=90) 
# only plot every 5th year to avoid overcrowding the x axis
plt.xticks(years[::4])



plt.ylabel('Millions of Euros')
plt.title('Value over Time')
plt.legend()
plt.show()


'''
# Out:
# '\n# print the data to see what it looks like\nprint(data)\n# extract the relevant data from the json file\n# the data is in the "value" key of the json file\nvalues_list = data[\'value\']\n# print the values to see what they look like\n\nprint(values_list)\n# the years are in the dimension \'TLIST(Q1)\'\nyears = list(data[\'dimension\'][\'TLIST(Q1)\'][\'category\'][\'label\'].values())\n# print the years and values to see what they look like\nprint(years)\nprint(values_list)\n# we can now create a line graph of the data using matplotlib\nimport matplotlib.pyplot as plt\n\n# Extract category labels\ncategories = list(data[\'dimension\'][\'C02568V03113\'][\'category\'][\'label\'].values())\nplt.figure(figsize=(10, 6))\n\n# Plot each series\nfor i in range(len(categories)):\n    series = values_list[i * len(years):(i + 1) * len(years)]\n    plt.plot(years, series, label=categories[i])\n\nplt.xlabel(\'Year\')\nplt.xticks(rotation=90) \n# only plot every 5th year to avoid overcrowding th
# ...
